# %%
import requests
from dotenv import load_dotenv
import os

# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
load_dotenv()
API_KEY = os.getenv("THE_ODDS_API_KEY")
if not API_KEY:
    raise ValueError("No API key found. Please set the THE_ODDS_API_KEY environment variable.")
# americanfootball_nfl
# americanfootball_ncaaf
# baseball_mlb
SPORT = 'americanfootball_ncaaf' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us,us2' # uk | us | eu | au. Multiple can be specified if comma delimited

# h2h
MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': API_KEY
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())
# Out:
# List of in season sports: [{'key': 'americanfootball_cfl', 'group': 'American Football', 'title': 'CFL', 'description': 'Canadian Football League', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf_championship_winner', 'group': 'American Football', 'title': 'NCAAF Championship Winner', 'description': 'US College Football Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2025/2026', 'active': True, 'has_outrights': True}, {'key': 'aussierules_afl', 'group': 'Aussie Rules', 'title': 'AFL', 'description': 'Aussie Football', 'active': True, 'has_outrights': False}, {'key': 'baseball_milb', 'group': 'Baseball', 'title': 'MiLB', 'description': 'Minor League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2025', 'active': True, 'has_outrights': True}, {'key': 'baseball_npb', 'group': 'Baseball', 'title': 'NPB', 'description': 'Nippon Professional Baseball', 'active': True, 'has_outrights': False}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2025/2026', 'active': True, 'has_outrights': True}, {'key': 'basketball_nbl', 'group': 'Basketball', 'title': 'NBL', 'description': 'AU National Basketball League', 'active': True, 'has_outrights': False}, {'key': 'basketball_ncaab_championship_winner', 'group': 'Basketball', 'title': 'NCAAB Championship Winner', 'description': 'US College Basketball Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'basketball_wnba', 'group': 'Basketball', 'title': 'WNBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'boxing_boxing', 'group': 'Boxing', 'title': 'Boxing', 'description': 'Boxing Bouts', 'active': True, 'has_outrights': False}, {'key': 'cricket_asia_cup', 'group': 'Cricket', 'title': 'Asia Cup', 'description': 'Asia Cup', 'active': True, 'has_outrights': False}, {'key': 'cricket_caribbean_premier_league', 'group': 'Cricket', 'title': 'CPLT20', 'description': 'Caribbean Premier League', 'active': True, 'has_outrights': False}, {'key': 'cricket_international_t20', 'group': 'Cricket', 'title': 'International Twenty20', 'description': 'International Twenty20', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2026 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_liiga', 'group': 'Ice Hockey', 'title': 'Liiga', 'description': 'Finnish SM League', 'active': True, 'has_outrights': False}, {'key': 'icehockey_mestis', 'group': 'Ice Hockey', 'title': 'Mestis', 'description': 'Finnish Mestis League', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner ...

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of markets
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports/{SPORT}/events/', 
    params={
        'api_key': API_KEY
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())
# Out:
# Failed to get sports: status_code 404, response body {"message":"Unknown sport","error_code":"UNKNOWN_SPORT","details_url":"https://the-odds-api.com/liveapi/guides/v4/api-error-codes.html#unknown-sport"}

# %%
sports_keys = [x['key'] for x in sports_response.json()]
print(sports_keys)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sports_keys = [x['key'] for x in sports_response.json()]
#       2 print(sports_keys)
#
# TypeError: string indices must be integers, not 'str'

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Number of events: 75
# [{'id': 'f7f75940634e8ec62dac353f09be0677', 'sport_key': 'americanfootball_ncaaf', 'sport_title': 'NCAAF', 'commence_time': '2025-09-19T23:30:00Z', 'home_team': 'Oklahoma State Cowboys', 'away_team': 'Tulsa Golden Hurricane', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2025-09-19T19:00:37Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:37Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.29}, {'name': 'Tulsa Golden Hurricane', 'price': 3.7}]}]}, {'key': 'fliff', 'title': 'Fliff', 'last_update': '2025-09-19T19:00:35Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:34Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.24}, {'name': 'Tulsa Golden Hurricane', 'price': 3.8}]}]}, {'key': 'espnbet', 'title': 'ESPN BET', 'last_update': '2025-09-19T19:00:04Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:04Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.25}, {'name': 'Tulsa Golden Hurricane', 'price': 4.0}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2025-09-19T19:00:02Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:02Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.28}, {'name': 'Tulsa Golden Hurricane', 'price': 3.85}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2025-09-19T19:00:01Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:00Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.26}, {'name': 'Tulsa Golden Hurricane', 'price': 3.9}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2025-09-19T18:56:32Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T18:56:32Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.25}, {'name': 'Tulsa Golden Hurricane', 'price': 3.7}]}]}, {'key': 'ballybet', 'title': 'Bally Bet', 'last_update': '2025-09-19T19:00:01Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:01Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.25}, {'name': 'Tulsa Golden Hurricane', 'price': 3.7}]}]}, {'key': 'betparx', 'title': 'betPARX', 'last_update': '2025-09-19T18:59:43Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T18:59:43Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.25}, {'name': 'Tulsa Golden Hurricane', 'price': 3.7}]}]}, {'key': 'hardrockbet', 'title': 'Hard Rock Bet', 'last_update': '2025-09-19T19:00:01Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:01Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.27}, {'name': 'Tulsa Golden Hurricane', 'price': 3.75}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2025-09-19T18:58:33Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T18:58:33Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.27}, {'name': 'Tulsa Golden Hurricane', 'price': 3.92}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2025-09-19T18:59:18Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T18:59:18Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.27}, {'name': 'Tulsa Golden Hurricane', 'price': 3.92}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2025-09-19T19:00:01Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:01Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.29}, {'name': 'Tulsa Golden Hurricane', 'price': 3.8}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2025-09-19T19:00:01Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:01Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.27}, {'name': 'Tulsa Golden Hurricane', 'price': 3.9}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2025-09-19T19:00:38Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-19T19:00:37Z', 'outcomes': [{'name': 'Oklahoma State Cowboys', 'price': 1.24}, {'name': 'Tulsa Golden Hurricane', 'price': 4.05}]}]}]}, {'id': '4bab9cbac51f27b9f12617b760247074', 'sport_key': ...
# Remaining requests 432
# Used requests 68

# %%
first_game = odds_response.json()[11]
first_game['bookmakers']
# Out:
# [{'key': 'betonlineag',
#   'title': 'BetOnline.ag',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.96},
#      {'name': 'Texas Rangers', 'price': 1.94}]}]},
#  {'key': 'lowvig',
#   'title': 'LowVig.ag',
#   'last_update': '2025-09-16T22:24:34Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:34Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.96},
#      {'name': 'Texas Rangers', 'price': 1.94}]}]},
#  {'key': 'mybookieag',
#   'title': 'MyBookie.ag',
#   'last_update': '2025-09-16T22:23:27Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:23:27Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.93},
#      {'name': 'Texas Rangers', 'price': 1.92}]}]},
#  {'key': 'fanduel',
#   'title': 'FanDuel',
#   'last_update': '2025-09-16T22:24:21Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:21Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.93},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'hardrockbet',
#   'title': 'Hard Rock Bet',
#   'last_update': '2025-09-16T22:23:58Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:23:58Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.95},
#      {'name': 'Texas Rangers', 'price': 1.87}]}]},
#  {'key': 'espnbet',
#   'title': 'ESPN BET',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 2.0},
#      {'name': 'Texas Rangers', 'price': 1.83}]}]},
#  {'key': 'draftkings',
#   'title': 'DraftKings',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.94},
#      {'name': 'Texas Rangers', 'price': 1.88}]}]},
#  {'key': 'betparx',
#   'title': 'betPARX',
#   'last_update': '2025-09-16T22:24:34Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:34Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.91},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'betrivers',
#   'title': 'BetRivers',
#   'last_update': '2025-09-16T22:24:13Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:13Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.89},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'ballybet',
#   'title': 'Bally Bet',
#   'last_update': '2025-09-16T22:24:21Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:21Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.91},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'fliff',
#   'title': 'Fliff',
#   'last_update': '2025-09-16T22:24:14Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:14Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.95},
#      {'name': 'Texas Rangers', 'price': 1.83}]}]},
#  {'key': 'betmgm',
#   'title': 'BetMGM',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.95},
#      {'name': 'Texas Rangers', 'price': 1.87}]}]},
#  {'key': 'bovada',
#   'title': 'Bovada',
#   'last_update': '2025-09-16T22:24:27Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:27Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.93},
#      {'name': 'Texas Rangers', 'price': 1.89}]}]},
#  {'key': 'betus',
#   'title': 'BetUS',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.97},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]}]

# %%
def decimal_to_implied_prob(decimal_odds):
    return 1 / decimal_odds

def process_game(game, valid_bookmakers=[], print_output=False):
    if print_output:
        print(game['home_team'], 'vs', game['away_team'])
        print('Commence time:', game['commence_time'])
    team_a_name = game['home_team']
    team_b_name = game['away_team']
    lowest_team_a = 1.0
    lowest_team_a_bookermaker = 'n/a'
    lowest_team_b = 1.0
    lowest_team_b_bookermaker = 'n/a'
    for bookmaker in game['bookmakers']:
        if len(valid_bookmakers) != 0 and bookmaker['title'] not in valid_bookmakers:
            continue
        
        if print_output:
            print('Bookmaker:', bookmaker['title'])

        for market in bookmaker['markets']:
            if market['key'] != 'h2h':
                continue
            if print_output:
                print(' Market:', market['key'])
            if market['outcomes'][0]['name'] == team_a_name and market['outcomes'][1]['name'] == team_b_name:
                team_a = market['outcomes'][0]
                team_b = market['outcomes'][1]
            elif market['outcomes'][0]['name'] == team_b_name and market['outcomes'][1]['name'] == team_a_name:
                team_a = market['outcomes'][1]
                team_b = market['outcomes'][0]
            else:
                if print_output:
                    print('  Skipping market {team_a_name} vs {team_b_name}, team names do not match')
                continue
            team_a_implied_prob = decimal_to_implied_prob(team_a['price'])
            team_b_implied_prob = decimal_to_implied_prob(team_b['price'])
            if print_output:
                print('  Outcome:', team_a['name'], 'Price:', team_a_implied_prob)
                print('  Outcome:', team_b['name'], 'Price:', team_b_implied_prob)
            if team_a_implied_prob < lowest_team_a:
                lowest_team_a = team_a_implied_prob
                lowest_team_a_bookermaker = bookmaker['title']
            elif team_a_implied_prob == lowest_team_a:
                lowest_team_a_bookermaker += ', ' + bookmaker['title']
            if team_b_implied_prob < lowest_team_b:
                lowest_team_b = team_b_implied_prob
                lowest_team_b_bookermaker = bookmaker['title']
            elif team_b_implied_prob == lowest_team_b:
                lowest_team_b_bookermaker += ', ' + bookmaker['title']

    if print_output:
        print('Best odds across all bookmakers:')
        print(lowest_team_a_bookermaker, ' - ', game['home_team'], ' - implied probability:', lowest_team_a)
        print(lowest_team_b_bookermaker, ' - ', game['away_team'], ' - implied probability:', lowest_team_b)
    
    return {
        'home_team': game['home_team'],
        'away_team': game['away_team'],
        'commence_time': game['commence_time'],
        'best_odds': {
            game['home_team']: {
                'implied_prob': lowest_team_a,
                'bookmaker': lowest_team_a_bookermaker
            },
            game['away_team']: {
                'implied_prob': lowest_team_b,
                'bookmaker': lowest_team_b_bookermaker
            }
        }
    }

# %%
valid_bookmakers = ['DraftKings', 'BetMGM', 'Caesars', 'FanDuel', 'ESPN BET']

for game in odds_response.json():
    processed_game = process_game(game, valid_bookmakers, print_output=False)
    sum = processed_game['best_odds'][processed_game['home_team']]['implied_prob'] + processed_game['best_odds'][processed_game['away_team']]['implied_prob']
    if sum < 2.015:
        print(processed_game['home_team'] + ' vs ' + processed_game['away_team'])
        print(processed_game['commence_time'])
        print('---')
        for team, odds in processed_game['best_odds'].items():
            print(odds['bookmaker'])
            print(team + ': ' + str(odds['implied_prob']))
        print(sum)
        print('######################################################################')
# Out:
# Oklahoma State Cowboys vs Tulsa Golden Hurricane
# 2025-09-19T23:30:00Z
# ---
# FanDuel
# Oklahoma State Cowboys: 0.7751937984496123
# ESPN BET
# Tulsa Golden Hurricane: 0.25
# 1.0251937984496124
# ######################################################################
# Rutgers Scarlet Knights vs Iowa Hawkeyes
# 2025-09-20T00:00:00Z
# ---
# ESPN BET
# Rutgers Scarlet Knights: 0.47619047619047616
# DraftKings, BetMGM
# Iowa Hawkeyes: 0.5555555555555556
# 1.0317460317460316
# ######################################################################
# Memphis Tigers vs Arkansas Razorbacks
# 2025-09-20T16:00:00Z
# ---
# DraftKings
# Memphis Tigers: 0.3076923076923077
# ESPN BET
# Arkansas Razorbacks: 0.7299270072992701
# 1.0376193149915778
# ######################################################################
# Army Black Knights vs North Texas Mean Green
# 2025-09-20T16:00:00Z
# ---
# FanDuel, ESPN BET
# Army Black Knights: 0.47619047619047616
# DraftKings, BetMGM
# North Texas Mean Green: 0.5555555555555556
# 1.0317460317460316
# ######################################################################
# Louisville Cardinals vs Bowling Green Falcons
# 2025-09-20T16:00:00Z
# ---
# DraftKings
# Louisville Cardinals: 0.970873786407767
# FanDuel
# Bowling Green Falcons: 0.058823529411764705
# 1.0296973158195317
# ######################################################################
# Clemson Tigers vs Syracuse Orange
# 2025-09-20T16:00:00Z
# ---
# FanDuel
# Clemson Tigers: 0.8849557522123894
# ESPN BET
# Syracuse Orange: 0.14285714285714285
# 1.0278128950695322
# ######################################################################
# Wisconsin Badgers vs Maryland Terrapins
# 2025-09-20T16:00:00Z
# ---
# DraftKings, FanDuel
# Wisconsin Badgers: 0.7751937984496123
# BetMGM
# Maryland Terrapins: 0.25641025641025644
# 1.0316040548598688
# ######################################################################
# TCU Horned Frogs vs SMU Mustangs
# 2025-09-20T16:00:00Z
# ---
# FanDuel
# TCU Horned Frogs: 0.6993006993006994
# DraftKings
# SMU Mustangs: 0.3278688524590164
# 1.027169551759716
# ######################################################################
# South Florida Bulls vs South Carolina State Bulldogs
# 2025-09-20T16:00:00Z
# ---
# FanDuel, DraftKings, ESPN BET
# South Florida Bulls: 0.9900990099009901
# DraftKings
# South Carolina State Bulldogs: 0.038461538461538464
# 1.0285605483625286
# ######################################################################
# Utah Utes vs Texas Tech Red Raiders
# 2025-09-20T16:00:00Z
# ---
# FanDuel
# Utah Utes: 0.6172839506172839
# ESPN BET
# Texas Tech Red Raiders: 0.4
# 1.017283950617284
# ######################################################################
# Virginia Tech Hokies vs Wofford Terriers
# 2025-09-20T16:00:00Z
# ---
# n/a
# Virginia Tech Hokies: 1.0
# n/a
# Wofford Terriers: 1.0
# 2.0
# ######################################################################
# Miami (OH) RedHawks vs UNLV Rebels
# 2025-09-20T16:05:00Z
# ---
# DraftKings, ESPN BET, BetMGM
# Miami (OH) RedHawks: 0.47619047619047616
# FanDuel
# UNLV Rebels: 0.5586592178770949
# 1.034849694067571
# ######################################################################
# Tennessee Volunteers vs UAB Blazers
# 2025-09-20T16:45:00Z
# ---
# n/a
# Tennessee Volunteers: 1.0
# n/a
# UAB Blazers: 1.0
# 2.0
# ######################################################################
# Central Michigan Chippewas vs Wagner Seahawks
# 2025-09-20T17:00:00Z
# ---
# FanDuel, DraftKings
# Central Michigan Chippewas: 0.9900990099009901
# DraftKings
# Wagner Seahawks: 0.03225806451612903
# 1.022357074417119
# ######################################################################
# Oregon Ducks vs Oregon State Beavers
# 2025-09-20T19:00:00Z
# ---
# n/a
# Oregon Ducks: 1.0
# n/a
# Oregon State Beavers: 1.0
# 2.0
# ######################################################################
# Oklahoma Sooners vs Auburn Tigers
# 2025-09-20T19:30:00Z
# ---
# FanDuel
# Oklahoma Sooners: 0.6993006993006994
# DraftKings, BetMGM, ESPN BET
# Auburn Tigers: 0.3333333333333333
# 1.0326340326340326
# ######################################################################
# UConn Huskies vs Ball State Cardinals
# 2025-09-20T19:30:00Z
# ---
# DraftKings, FanDuel, ESPN BET
# UConn Huskies: 0.9433962264150942
# DraftKings, BetMGM
# Ball State Cardinals: 0.09090909090909091
# 1.0343053173241852
# ######################################################################
# Buffalo Bulls vs Troy Trojans
# 2025-09-20T19:30:00Z
# ---
# DraftKings
# Buffalo Bulls: 0.6711409395973155
# BetMGM
# Troy Trojans: 0.3333333333333333
# 1.0044742729306488
# ######################################################################
# Eastern Michigan Eagles vs Louisiana Ragin Cajuns
# 2025-09-20T19:30:00Z
# ---
# DraftKings
# Eastern Michigan Eagles: 0.4672897196261682
# FanDuel
# Louisiana Ragin Cajuns: 0.5617977528089888
# 1.029087472435157
# ######################################################################
# Florida State Seminoles vs Kent State Golden Flashes
# 2025-09-20T19:30:00Z
# ---
# n/a
# Florida State Seminoles: 1.0
# n/a
# Kent State Golden Flashes: 1.0
# 2.0
# ######################################################################
# Ohio Bobcats vs Gardner-Webb Runnin Bulldogs
# 2025-09-20T19:30:00Z
# ---
# FanDuel, ESPN BET, DraftKings
# Ohio Bobcats: 0.9803921568627451
# DraftKings
# Gardner-Webb Runnin Bulldogs: 0.05555555555555555
# 1.0359477124183005
# ######################################################################
# Nebraska Cornhuskers vs Michigan Wolverines
# 2025-09-20T19:30:00Z
# ---
# BetMGM
# Nebraska Cornhuskers: 0.48780487804878053
# DraftKings
# Michigan Wolverines: 0.5405405405405405
# 1.028345418589321
# ######################################################################
# UCF Knights vs North Carolina Tar Heels
# 2025-09-20T19:30:00Z
# ---
# FanDuel
# UCF Knights: 0.7194244604316548
# BetMGM, ESPN BET
# North Carolina Tar Heels: 0.3076923076923077
# 1.0271167681239626
# ######################################################################
# Notre Dame Fighting Irish vs Purdue Boilermakers
# 2025-09-20T19:30:00Z
# ---
# DraftKings
# Notre Dame Fighting Irish: 0.970873786407767
# DraftKings, FanDuel, BetMGM
# Purdue Boilermakers: 0.06666666666666667
# 1.0375404530744337
# ######################################################################
# Ole Miss Rebels vs Tulane Green Wave
# 2025-09-20T19:30:00Z
# ---
# ESPN BET
# Ole Miss Rebels: 0.8064516129032259
# BetMGM
# Tulane Green Wave: 0.2173913043478261
# 1.023842917251052
# ######################################################################
# Western Michigan Broncos vs Toledo Rockets
# 2025-09-20T19:30:00Z
# ---
# FanDuel
# Western Michigan Broncos: 0.18181818181818182
# DraftKings, BetMGM
# Toledo Rockets: 0.8547008547008548
# 1.0365190365190367
# ######################################################################
# Duke Blue Devils vs NC State Wolfpack
# 2025-09-20T20:00:00Z
# ---
# BetMGM
# Duke Blue Devils: 0.5847953216374269
# ESPN BET
# NC State Wolfpack: 0.4347826086956522
# 1.019577930333079
# ######################################################################
# Mississippi State Bulldogs vs Northern Illinois Huskies
# 2025-09-20T20:15:00Z
# ---
# ESPN BET
# Mississippi State Bulldogs: 0.9523809523809523
# DraftKings
# Northern Illinois Huskies: 0.07142857142857142
# 1.0238095238095237
# ######################################################################
# Georgia Tech Yellow Jackets vs Temple Owls
# 2025-09-20T20:30:00Z
# ---
# FanDuel, DraftKings, BetMGM
# Georgia Tech Yellow Jackets: 0.9615384615384615
# DraftKings
# Temple Owls: 0.07142857142857142
# 1.0329670329670328
# ######################################################################
# San Jose State Spartans vs Idaho Vandals
# 2025-09-20T21:00:00Z
# ---
# DraftKings
# San Jose State Spartans: 0.8695652173913044
# FanDuel
# Idaho Vandals: 0.16666666666666666
# 1.0362318840579712
# ######################################################################
# Kennesaw State Owls vs Arkansas State Red Wolves
# 2025-09-20T22:00:00Z
# ---
# BetMGM, ESPN BET
# Kennesaw State Owls: 0.37735849056603776
# DraftKings, ESPN BET
# Arkansas State Red Wolves: 0.6622516556291391
# 1.039610146195177
# ######################################################################
# Florida International Panthers vs Delaware Blue Hens
# 2025-09-20T22:00:00Z
# ---
# FanDuel, BetMGM
# Florida International Panthers: 0.6666666666666666
# DraftKings
# Delaware Blue Hens: 0.37037037037037035
# 1.037037037037037
# ######################################################################
# Kansas Jayhawks vs West Virginia Mountaineers
# 2025-09-20T22:00:00Z
# ---
# DraftKings
# Kansas Jayhawks: 0.8264462809917356
# ESPN BET
# West Virginia Mountaineers: 0.20833333333333334
# 1.034779614325069
# ######################################################################
# Akron Zips vs Duquesne Dukes
# 2025-09-20T22:07:00Z
# ---
# FanDuel
# Akron Zips: 0.7352941176470588
# ESPN BET
# Duquesne Dukes: 0.2777777777777778
# 1.0130718954248366
# ######################################################################
# Liberty Flames vs James Madison Dukes
# 2025-09-20T22:07:00Z
# ---
# ESPN BET
# Liberty Flames: 0.25641025641025644
# BetMGM
# James Madison Dukes: 0.7633587786259541
# 1.0197690350362105
# ######################################################################
# Air Force Falcons vs Boise State Broncos
# 2025-09-20T23:00:00Z
# ---
# DraftKings
# Air Force Falcons: 0.23255813953488372
# BetMGM
# Boise State Broncos: 0.8
# 1.0325581395348837
# ######################################################################
# South Alabama Jaguars vs Coastal Carolina Chanticleers
# 2025-09-20T23:00:00Z
# ---
# FanDuel
# South Alabama Jaguars: 0.8695652173913044
# DraftKings
# Coastal Carolina Chanticleers: 0.15384615384615385
# 1.0234113712374584
# ######################################################################
# Middle Tennessee Blue Raiders vs Marshall Thundering Herd
# 2025-09-20T23:00:00Z
# ---
# FanDuel
# Middle Tennessee Blue Raiders: 0.4629629629629629
# ESPN BET
# Marshall Thundering Herd: 0.5649717514124294
# 1.0279347143753923
# ######################################################################
# Missouri Tigers vs South Carolina Gamecocks
# 2025-09-20T23:00:00Z
# ---
# FanDuel
# Missouri Tigers: 0.7692307692307692
# ESPN BET
# South Carolina Gamecocks: 0.25641025641025644
# 1.0256410256410255
# ######################################################################
# Western Kentucky Hilltoppers vs Nevada Wolf Pack
# 2025-09-20T23:00:00Z
# ---
# FanDuel
# Western Kentucky Hilltoppers: 0.7633587786259541
# BetMGM
# Nevada Wolf Pack: 0.25641025641025644
# 1.0197690350362105
# ######################################################################
# Georgia Southern Eagles vs Maine Black Bears
# 2025-09-20T23:07:00Z
# ---
# FanDuel, DraftKings
# Georgia Southern Eagles: 0.9615384615384615
# ESPN BET
# Maine Black Bears: 0.0625
# 1.0240384615384615
# ######################################################################
# Jacksonville State Gamecocks vs Murray State Racers
# 2025-09-20T23:07:00Z
# ---
# n/a
# Jacksonville State Gamecocks: 1.0
# n/a
# Murray State Racers: 1.0
# 2.0
# ######################################################################
# Missouri State Bears vs UT Martin Skyhawks
# 2025-09-20T23:07:00Z
# ---
# DraftKings
# Missouri State Bears: 0.8403361344537815
# FanDuel
# UT Martin Skyhawks: 0.1923076923076923
# 1.0326438267614737
# ######################################################################
# Baylor Bears vs Arizona State Sun Devils
# 2025-09-20T23:30:00Z
# ---
# DraftKings
# Baylor Bears: 0.5649717514124294
# ESPN BET
# Arizona State Sun Devils: 0.46511627906976744
# 1.0300880304821969
# ######################################################################
# East Carolina Pirates vs BYU Cougars
# 2025-09-20T23:30:00Z
# ---
# DraftKings, BetMGM, ESPN BET
# East Carolina Pirates: 0.3389830508474576
# FanDuel, BetMGM, ESPN BET
# BYU Cougars: 0.6993006993006994
# 1.038283750148157
# ######################################################################
# Miami Hurricanes vs Florida Gators
# 2025-09-20T23:30:00Z
# ---
# FanDuel
# Miami Hurricanes: 0.7462686567164178
# BetMGM
# Florida Gators: 0.26666666666666666
# 1.0129353233830845
# ######################################################################
# Vanderbilt Commodores vs Georgia State Panthers
# 2025-09-20T23:30:00Z
# ---
# DraftKings, FanDuel, BetMGM
# Vanderbilt Commodores: 0.9803921568627451
# DraftKings
# Georgia State Panthers: 0.05555555555555555
# 1.0359477124183005
# ######################################################################
# Indiana Hoosiers vs Illinois Fighting Illini
# 2025-09-20T23:30:00Z
# ---
# FanDuel
# Indiana Hoosiers: 0.6993006993006994
# DraftKings, ESPN BET
# Illinois Fighting Illini: 0.3225806451612903
# 1.0218813444619896
# ######################################################################
# Louisiana Tech Bulldogs vs Southern Mississippi Golden Eagles
# 2025-09-20T23:30:00Z
# ---
# ESPN BET
# Louisiana Tech Bulldogs: 0.6060606060606061
# BetMGM
# Southern Mississippi Golden Eagles: 0.4166666666666667
# 1.0227272727272727
# ######################################################################
# Virginia Cavaliers vs Stanford Cardinal
# 2025-09-20T23:30:00Z
# ---
# FanDuel
# Virginia Cavaliers: 0.8771929824561404
# DraftKings, BetMGM, ESPN BET
# Stanford Cardinal: 0.15384615384615385
# 1.0310391363022942
# ######################################################################
# Washington State Cougars vs Washington Huskies
# 2025-09-20T23:30:00Z
# ---
# ESPN BET
# Washington State Cougars: 0.1
# DraftKings, BetMGM
# Washington Huskies: 0.9259259259259258
# 1.025925925925926
# ######################################################################
# LSU Tigers vs Southeastern Louisiana Lions
# 2025-09-20T23:52:00Z
# ---
# n/a
# LSU Tigers: 1.0
# n/a
# Southeastern Louisiana Lions: 1.0
# 2.0
# ######################################################################
# Texas Longhorns vs Sam Houston State Bearkats
# 2025-09-21T00:00:00Z
# ---
# n/a
# Texas Longhorns: 1.0
# n/a
# Sam Houston State Bearkats: 1.0
# 2.0
# ######################################################################
# Utah State Aggies vs McNeese State Cowboys
# 2025-09-21T00:07:00Z
# ---
# FanDuel, DraftKings
# Utah State Aggies: 0.9615384615384615
# DraftKings
# McNeese State Cowboys: 0.07142857142857142
# 1.0329670329670328
# ######################################################################
# Texas State Bobcats vs Nicholls State Colonels
# 2025-09-21T00:07:00Z
# ---
# DraftKings
# Texas State Bobcats: 0.9803921568627451
# FanDuel, DraftKings
# Nicholls State Colonels: 0.047619047619047616
# 1.0280112044817926
# ######################################################################
# UTEP Miners vs UL Monroe Warhawks
# 2025-09-21T01:00:00Z
# ---
# FanDuel, BetMGM
# UTEP Miners: 0.7142857142857143
# ESPN BET
# UL Monroe Warhawks: 0.3125
# 1.0267857142857144
# ######################################################################
# Colorado State Rams vs UTSA Roadrunners
# 2025-09-21T01:30:00Z
# ---
# ESPN BET
# Colorado State Rams: 0.37037037037037035
# FanDuel
# UTSA Roadrunners: 0.6535947712418301
# 1.0239651416122004
# ######################################################################
# Colorado Buffaloes vs Wyoming Cowboys
# 2025-09-21T02:15:00Z
# ---
# DraftKings
# Colorado Buffaloes: 0.8403361344537815
# FanDuel, BetMGM
# Wyoming Cowboys: 0.2
# 1.0403361344537816
# ######################################################################
# San Diego State Aztecs vs California Golden Bears
# 2025-09-21T02:30:00Z
# ---
# BetMGM, ESPN BET
# San Diego State Aztecs: 0.2
# FanDuel
# California Golden Bears: 0.8264462809917356
# 1.0264462809917356
# ######################################################################
# USC Trojans vs Michigan State Spartans
# 2025-09-21T03:00:00Z
# ---
# DraftKings
# USC Trojans: 0.9009009009009008
# FanDuel
# Michigan State Spartans: 0.13157894736842105
# 1.0324798482693218
# ######################################################################
# Hawaii Rainbow Warriors vs Fresno State Bulldogs
# 2025-09-21T03:59:00Z
# ---
# DraftKings, ESPN BET
# Hawaii Rainbow Warriors: 0.4347826086956522
# BetMGM, ESPN BET
# Fresno State Bulldogs: 0.5988023952095809
# 1.033585003905233
# ######################################################################
# Virginia Cavaliers vs Florida State Seminoles
# 2025-09-26T23:00:00Z
# ---
# FanDuel
# Virginia Cavaliers: 0.29411764705882354
# FanDuel
# Florida State Seminoles: 0.7518796992481203
# 1.0459973463069439
# ######################################################################
# Arizona State Sun Devils vs TCU Horned Frogs
# 2025-09-27T01:00:00Z
# ---
# n/a
# Arizona State Sun Devils: 1.0
# n/a
# TCU Horned Frogs: 1.0
# 2.0
# ######################################################################
# Arkansas Razorbacks vs Notre Dame Fighting Irish
# 2025-09-27T16:00:00Z
# ---
# FanDuel
# Arkansas Razorbacks: 0.35211267605633806
# FanDuel
# Notre Dame Fighting Irish: 0.6944444444444444
# 1.0465571205007824
# ######################################################################
# Texas A&M Aggies vs Auburn Tigers
# 2025-09-27T19:30:00Z
# ---
# FanDuel
# Texas A&M Aggies: 0.7142857142857143
# FanDuel
# Auburn Tigers: 0.33112582781456956
# 1.0454115421002839
# ######################################################################
# Illinois Fighting Illini vs USC Trojans
# 2025-09-27T19:30:00Z
# ---
# FanDuel
# Illinois Fighting Illini: 0.4716981132075471
# FanDuel
# USC Trojans: 0.5714285714285714
# 1.0431266846361185
# ######################################################################
# Ole Miss Rebels vs LSU Tigers
# 2025-09-27T19:30:00Z
# ---
# FanDuel
# Ole Miss Rebels: 0.5235602094240838
# FanDuel
# LSU Tigers: 0.5235602094240838
# 1.0471204188481675
# ######################################################################
# Mississippi State Bulldogs vs Tennessee Volunteers
# 2025-09-27T20:15:00Z
# ---
# FanDuel
# Mississippi State Bulldogs: 0.2777777777777778
# FanDuel
# Tennessee Volunteers: 0.7692307692307692
# 1.0470085470085468
# ######################################################################
# Iowa State Cyclones vs Arizona Wildcats
# 2025-09-27T23:00:00Z
# ---
# FanDuel
# Iowa State Cyclones: 0.7407407407407407
# FanDuel
# Arizona Wildcats: 0.30303030303030304
# 1.0437710437710437
# ######################################################################
# Iowa Hawkeyes vs Indiana Hoosiers
# 2025-09-27T23:00:00Z
# ---
# FanDuel
# Iowa Hawkeyes: 0.4587155963302752
# FanDuel
# Indiana Hoosiers: 0.5882352941176471
# 1.0469508904479223
# ######################################################################
# Washington Huskies vs Ohio State Buckeyes
# 2025-09-27T23:00:00Z
# ---
# FanDuel
# Washington Huskies: 0.18518518518518517
# FanDuel
# Ohio State Buckeyes: 0.8620689655172414
# 1.0472541507024267
# ######################################################################
# Georgia Bulldogs vs Alabama Crimson Tide
# 2025-09-27T23:30:00Z
# ---
# FanDuel
# Georgia Bulldogs: 0.6211180124223602
# FanDuel
# Alabama Crimson Tide: 0.42372881355932207
# 1.0448468259816823
# ######################################################################
# Penn State Nittany Lions vs Oregon Ducks
# 2025-09-27T23:30:00Z
# ---
# FanDuel
# Penn State Nittany Lions: 0.6172839506172839
# FanDuel
# Oregon Ducks: 0.4310344827586207
# 1.0483184333759046
# ######################################################################
# Texas Longhorns vs Oklahoma Sooners
# 2025-10-11T19:30:00Z
# ---
# FanDuel
# Texas Longhorns: 0.6289308176100629
# FanDuel
# Oklahoma Sooners: 0.4166666666666667
# 1.0455974842767295
# ######################################################################
# Michigan Wolverines vs Ohio State Buckeyes
# 2025-11-29T17:00:00Z
# ---
# FanDuel
# Michigan Wolverines: 0.2857142857142857
# FanDuel
# Ohio State Buckeyes: 0.7575757575757576
# 1.0432900432900434
# ######################################################################

# %%
# This is for individual bookmakers only

valid_bookmakers = ['BetMGM']

for game in odds_response.json():
    processed_game = process_game(game, valid_bookmakers, print_output=False)
    sum = processed_game['best_odds'][processed_game['home_team']]['implied_prob'] + processed_game['best_odds'][processed_game['away_team']]['implied_prob']
    best_odds = max(processed_game['best_odds'][processed_game['home_team']]['implied_prob'], processed_game['best_odds'][processed_game['away_team']]['implied_prob'])
    if sum < 2:
        # print(processed_game['home_team'] + ' vs ' + processed_game['away_team'])
        # print(processed_game['commence_time'])
        # print('---')
        for team, odds in processed_game['best_odds'].items():
            # print(odds['bookmaker'])
            print(team + ': ' + str(odds['implied_prob']))
        print(sum)
        print('######################################################################')
# Out:
# Houston Cougars: 0.3921568627450981
# Colorado Buffaloes: 0.6535947712418301
# 1.0457516339869282
# ######################################################################
# Arizona Wildcats: 0.5128205128205129
# Kansas State Wildcats: 0.53475935828877
# 1.0475798711092827
# ######################################################################
# UCLA Bruins: 0.17391304347826086
# New Mexico Lobos: 0.8695652173913044
# 1.0434782608695654
# ######################################################################
# Alabama Crimson Tide: 0.9523809523809523
# Wisconsin Badgers: 0.09523809523809523
# 1.0476190476190474
# ######################################################################
# Kent State Golden Flashes: 0.9615384615384615
# Buffalo Bulls: 0.08333333333333333
# 1.0448717948717947
# ######################################################################
# Michigan Wolverines: 0.058823529411764705
# Central Michigan Chippewas: 0.9803921568627451
# 1.0392156862745097
# ######################################################################
# Georgia Tech Yellow Jackets: 0.591715976331361
# Clemson Tigers: 0.45454545454545453
# 1.0462614308768154
# ######################################################################
# Troy Trojans: 0.6493506493506493
# Memphis Tigers: 0.4
# 1.0493506493506493
# ######################################################################
# Northwestern Wildcats: 0.047619047619047616
# Oregon Ducks: 0.9900990099009901
# 1.0377180575200378
# ######################################################################
# Temple Owls: 0.9615384615384615
# Oklahoma Sooners: 0.08695652173913043
# 1.0484949832775918
# ######################################################################
# Auburn Tigers: 0.9803921568627451
# South Alabama Jaguars: 0.06896551724137931
# 1.0493576741041244
# ######################################################################
# Missouri Tigers: 0.047619047619047616
# Louisiana Ragin Cajuns: 0.9900990099009901
# 1.0377180575200378
# ######################################################################
# Delaware Blue Hens: 0.2777777777777778
# UConn Huskies: 0.7633587786259541
# 1.0411365564037318
# ######################################################################
# Tennessee Volunteers: 0.6493506493506493
# Georgia Bulldogs: 0.4
# 1.0493506493506493
# ######################################################################
# Missouri State Bears: 0.05555555555555555
# SMU Mustangs: 0.9900990099009901
# 1.0456545654565457
# ######################################################################
# North Texas Mean Green: 0.6756756756756757
# Washington State Cougars: 0.37037037037037035
# 1.0460460460460461
# ######################################################################
# Texas Tech Red Raiders: 0.08333333333333333
# Oregon State Beavers: 0.9615384615384615
# 1.0448717948717947
# ######################################################################
# West Virginia Mountaineers: 0.7518796992481203
# Pittsburgh Panthers: 0.29411764705882354
# 1.0459973463069439
# ######################################################################
# Purdue Boilermakers: 0.1111111111111111
# USC Trojans: 0.9345794392523364
# 1.0456905503634475
# ######################################################################
# Arkansas State Red Wolves: 0.10256410256410256
# Iowa State Cyclones: 0.9433962264150942
# 1.0459603289791968
# ######################################################################
# Miami Hurricanes: 0.9009009009009008
# South Florida Bulls: 0.14285714285714285
# 1.0437580437580436
# ######################################################################
# Bowling Green Falcons: 0.37735849056603776
# Liberty Flames: 0.6666666666666666
# 1.0440251572327044
# ######################################################################
# Nevada Wolf Pack: 0.2631578947368421
# Middle Tennessee Blue Raiders: 0.7751937984496123
# 1.0383516931864545
# ######################################################################
# Florida International Panthers: 0.47619047619047616
# Florida Atlantic Owls: 0.5747126436781609
# 1.0509031198686372
# ######################################################################
# Southern Mississippi Golden Eagles: 0.6369426751592356
# Appalachian State Mountaineers: 0.4081632653061224
# 1.045105940465358
# ######################################################################
# Ole Miss Rebels: 0.3389830508474576
# Arkansas Razorbacks: 0.6993006993006994
# 1.038283750148157
# ######################################################################
# Georgia Southern Eagles: 0.6172839506172839
# Jacksonville State Gamecocks: 0.425531914893617
# 1.042815865510901
# ######################################################################
# Illinois Fighting Illini: 0.9900990099009901
# Western Michigan Broncos: 0.047619047619047616
# 1.0377180575200378
# ######################################################################
# Virginia Tech Hokies: 0.35714285714285715
# Old Dominion Monarchs: 0.6896551724137931
# 1.0467980295566504
# ######################################################################
# South Carolina Gamecocks: 0.6172839506172839
# Vanderbilt Commodores: 0.425531914893617
# 1.042815865510901
# ######################################################################
# Coastal Carolina Chanticleers: 0.2777777777777778
# East Carolina Pirates: 0.7633587786259541
# 1.0411365564037318
# ######################################################################
# Kentucky Wildcats: 0.07142857142857142
# Eastern Michigan Eagles: 0.970873786407767
# 1.0423023578363384
# ######################################################################
# LSU Tigers: 0.3076923076923077
# Florida Gators: 0.7407407407407407
# 1.0484330484330484
# ######################################################################
# Louisiana Tech Bulldogs: 0.7874015748031495
# New Mexico State Aggies: 0.2631578947368421
# 1.0505594695399916
# ######################################################################
# Notre Dame Fighting Irish: 0.6993006993006994
# Texas A&M Aggies: 0.3448275862068966
# 1.044128285507596
# ######################################################################
# Tulane Green Wave: 0.5
# Duke Blue Devils: 0.5464480874316939
# 1.046448087431694
# ######################################################################
# Tulsa Golden Hurricane: 0.8620689655172414
# Navy Midshipmen: 0.18181818181818182
# 1.0438871473354232
# ######################################################################
# Wyoming Cowboys: 0.970873786407767
# Utah Utes: 0.07142857142857142
# 1.0423023578363384
# ######################################################################
# UAB Blazers: 0.2222222222222222
# Akron Zips: 0.819672131147541
# 1.0418943533697633
# ######################################################################
# Utah State Aggies: 0.6666666666666666
# Air Force Falcons: 0.37735849056603776
# 1.0440251572327044
# ######################################################################
# Arizona State Sun Devils: 0.9009009009009008
# Texas State Bobcats: 0.14285714285714285
# 1.0437580437580436
# ######################################################################
# Stanford Cardinal: 0.8547008547008548
# Boston College Eagles: 0.19047619047619047
# 1.0451770451770452
# ######################################################################
# California Golden Bears: 0.45454545454545453
# Minnesota Golden Gophers: 0.591715976331361
# 1.0462614308768154
# ######################################################################
