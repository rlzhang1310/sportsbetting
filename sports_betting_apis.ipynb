# %%
import requests

# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
API_KEY = 'c146d41ee6fa4c4af149f4965849f905'

# americanfootball_nfl
# americanfootball_ncaaf
# baseball_mlb
SPORT = 'americanfootball_nfl' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us,us2' # uk | us | eu | au. Multiple can be specified if comma delimited

# h2h
MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': API_KEY
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())
# Out:
# List of in season sports: [{'key': 'americanfootball_cfl', 'group': 'American Football', 'title': 'CFL', 'description': 'Canadian Football League', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf_championship_winner', 'group': 'American Football', 'title': 'NCAAF Championship Winner', 'description': 'US College Football Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2025/2026', 'active': True, 'has_outrights': True}, {'key': 'aussierules_afl', 'group': 'Aussie Rules', 'title': 'AFL', 'description': 'Aussie Football', 'active': True, 'has_outrights': False}, {'key': 'baseball_kbo', 'group': 'Baseball', 'title': 'KBO', 'description': 'KBO League', 'active': True, 'has_outrights': False}, {'key': 'baseball_milb', 'group': 'Baseball', 'title': 'MiLB', 'description': 'Minor League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2025', 'active': True, 'has_outrights': True}, {'key': 'baseball_npb', 'group': 'Baseball', 'title': 'NPB', 'description': 'Nippon Professional Baseball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2025/2026', 'active': True, 'has_outrights': True}, {'key': 'basketball_nbl', 'group': 'Basketball', 'title': 'NBL', 'description': 'AU National Basketball League', 'active': True, 'has_outrights': False}, {'key': 'basketball_ncaab_championship_winner', 'group': 'Basketball', 'title': 'NCAAB Championship Winner', 'description': 'US College Basketball Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'basketball_wnba', 'group': 'Basketball', 'title': 'WNBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'boxing_boxing', 'group': 'Boxing', 'title': 'Boxing', 'description': 'Boxing Bouts', 'active': True, 'has_outrights': False}, {'key': 'cricket_asia_cup', 'group': 'Cricket', 'title': 'Asia Cup', 'description': 'Asia Cup', 'active': True, 'has_outrights': False}, {'key': 'cricket_caribbean_premier_league', 'group': 'Cricket', 'title': 'CPLT20', 'description': 'Caribbean Premier League', 'active': True, 'has_outrights': False}, {'key': 'cricket_international_t20', 'group': 'Cricket', 'title': 'International Twenty20', 'description': 'International Twenty20', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2026 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_liiga', 'group': 'Ice Hockey', 'title': 'Liiga', 'description': 'Finnish SM League', 'active': True, 'has_outrights': False}, {'key': 'icehockey_mestis', 'group': 'Ice Hockey', 'title': 'Mestis', 'description': 'Finnish Mestis League', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 20 ...

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of markets
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports/{SPORT}/events/', 
    params={
        'api_key': API_KEY
    }
)


if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())
# Out:
# Failed to get sports: status_code 404, response body {"message":"Unknown sport","error_code":"UNKNOWN_SPORT","details_url":"https://the-odds-api.com/liveapi/guides/v4/api-error-codes.html#unknown-sport"}

# %%
sports_keys = [x['key'] for x in sports_response.json()]
print(sports_keys)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sports_keys = [x['key'] for x in sports_response.json()]
#       2 print(sports_keys)
#
# TypeError: string indices must be integers, not 'str'

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# Now get a list of live & upcoming games for the sport you want, along with odds for different bookmakers
# This will deduct from the usage quota
# The usage quota cost = [number of markets specified] x [number of regions specified]
# For examples of usage quota costs, see https://the-odds-api.com/liveapi/guides/v4/#usage-quota-costs
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Number of events: 32
# [{'id': 'aca5234c57e31b1931e51d2d0d6046f5', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-09-19T00:15:00Z', 'home_team': 'Buffalo Bills', 'away_team': 'Miami Dolphins', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2025-09-18T20:11:24Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:24Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.12}, {'name': 'Miami Dolphins', 'price': 6.75}]}]}, {'key': 'hardrockbet', 'title': 'Hard Rock Bet', 'last_update': '2025-09-18T20:12:09Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:12:09Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 7.0}]}]}, {'key': 'espnbet', 'title': 'ESPN BET', 'last_update': '2025-09-18T20:11:25Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:25Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 6.5}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2025-09-18T20:12:08Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:12:08Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.12}, {'name': 'Miami Dolphins', 'price': 6.9}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2025-09-18T20:10:55Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:10:55Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.1}, {'name': 'Miami Dolphins', 'price': 7.28}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2025-09-18T20:11:40Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:39Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.12}, {'name': 'Miami Dolphins', 'price': 6.8}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2025-09-18T20:11:24Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:24Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 7.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2025-09-18T20:11:35Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:34Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 7.0}]}]}, {'key': 'fliff', 'title': 'Fliff', 'last_update': '2025-09-18T20:11:22Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:22Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 6.45}]}]}, {'key': 'ballybet', 'title': 'Bally Bet', 'last_update': '2025-09-18T20:11:25Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:11:25Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 7.0}]}]}, {'key': 'betparx', 'title': 'betPARX', 'last_update': '2025-09-18T20:12:08Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:12:08Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 7.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2025-09-18T20:12:09Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:12:09Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.1}, {'name': 'Miami Dolphins', 'price': 6.75}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2025-09-18T20:10:55Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:10:55Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 6.75}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2025-09-18T20:12:07Z', 'markets': [{'key': 'h2h', 'last_update': '2025-09-18T20:12:07Z', 'outcomes': [{'name': 'Buffalo Bills', 'price': 1.11}, {'name': 'Miami Dolphins', 'price': 7.0}]}]}]}, {'id': '5737e4dbf6879c5061bb23033a4d8a55', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2025-09-21T17:00:00Z', 'home_team': 'Carolina Panthers', 'away_team': 'Atlanta Falcons', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2025-09-18T20:11:24Z', 'markets ...
# Remaining requests 478
# Used requests 22

# %%
first_game = odds_response.json()[11]
first_game['bookmakers']
# Out:
# [{'key': 'betonlineag',
#   'title': 'BetOnline.ag',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.96},
#      {'name': 'Texas Rangers', 'price': 1.94}]}]},
#  {'key': 'lowvig',
#   'title': 'LowVig.ag',
#   'last_update': '2025-09-16T22:24:34Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:34Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.96},
#      {'name': 'Texas Rangers', 'price': 1.94}]}]},
#  {'key': 'mybookieag',
#   'title': 'MyBookie.ag',
#   'last_update': '2025-09-16T22:23:27Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:23:27Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.93},
#      {'name': 'Texas Rangers', 'price': 1.92}]}]},
#  {'key': 'fanduel',
#   'title': 'FanDuel',
#   'last_update': '2025-09-16T22:24:21Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:21Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.93},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'hardrockbet',
#   'title': 'Hard Rock Bet',
#   'last_update': '2025-09-16T22:23:58Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:23:58Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.95},
#      {'name': 'Texas Rangers', 'price': 1.87}]}]},
#  {'key': 'espnbet',
#   'title': 'ESPN BET',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 2.0},
#      {'name': 'Texas Rangers', 'price': 1.83}]}]},
#  {'key': 'draftkings',
#   'title': 'DraftKings',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.94},
#      {'name': 'Texas Rangers', 'price': 1.88}]}]},
#  {'key': 'betparx',
#   'title': 'betPARX',
#   'last_update': '2025-09-16T22:24:34Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:34Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.91},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'betrivers',
#   'title': 'BetRivers',
#   'last_update': '2025-09-16T22:24:13Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:13Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.89},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'ballybet',
#   'title': 'Bally Bet',
#   'last_update': '2025-09-16T22:24:21Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:21Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.91},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]},
#  {'key': 'fliff',
#   'title': 'Fliff',
#   'last_update': '2025-09-16T22:24:14Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:14Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.95},
#      {'name': 'Texas Rangers', 'price': 1.83}]}]},
#  {'key': 'betmgm',
#   'title': 'BetMGM',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.95},
#      {'name': 'Texas Rangers', 'price': 1.87}]}]},
#  {'key': 'bovada',
#   'title': 'Bovada',
#   'last_update': '2025-09-16T22:24:27Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:27Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.93},
#      {'name': 'Texas Rangers', 'price': 1.89}]}]},
#  {'key': 'betus',
#   'title': 'BetUS',
#   'last_update': '2025-09-16T22:24:41Z',
#   'markets': [{'key': 'h2h',
#     'last_update': '2025-09-16T22:24:41Z',
#     'outcomes': [{'name': 'Houston Astros', 'price': 1.97},
#      {'name': 'Texas Rangers', 'price': 1.93}]}]}]

# %%
def decimal_to_implied_prob(decimal_odds):
    return 1 / decimal_odds

def process_game(game, valid_bookmakers=[], print_output=False):
    if print_output:
        print(game['home_team'], 'vs', game['away_team'])
        print('Commence time:', game['commence_time'])
    team_a_name = game['home_team']
    team_b_name = game['away_team']
    lowest_team_a = 1.0
    lowest_team_a_bookermaker = 'n/a'
    lowest_team_b = 1.0
    lowest_team_b_bookermaker = 'n/a'
    for bookmaker in game['bookmakers']:
        if len(valid_bookmakers) != 0 and bookmaker['title'] not in valid_bookmakers:
            continue
        
        if print_output:
            print('Bookmaker:', bookmaker['title'])

        for market in bookmaker['markets']:
            if market['key'] != 'h2h':
                continue
            if print_output:
                print(' Market:', market['key'])
            if market['outcomes'][0]['name'] == team_a_name and market['outcomes'][1]['name'] == team_b_name:
                team_a = market['outcomes'][0]
                team_b = market['outcomes'][1]
            elif market['outcomes'][0]['name'] == team_b_name and market['outcomes'][1]['name'] == team_a_name:
                team_a = market['outcomes'][1]
                team_b = market['outcomes'][0]
            else:
                if print_output:
                    print('  Skipping market {team_a_name} vs {team_b_name}, team names do not match')
                continue
            team_a_implied_prob = decimal_to_implied_prob(team_a['price'])
            team_b_implied_prob = decimal_to_implied_prob(team_b['price'])
            if print_output:
                print('  Outcome:', team_a['name'], 'Price:', team_a_implied_prob)
                print('  Outcome:', team_b['name'], 'Price:', team_b_implied_prob)
            if team_a_implied_prob < lowest_team_a:
                lowest_team_a = team_a_implied_prob
                lowest_team_a_bookermaker = bookmaker['title']
            elif team_a_implied_prob == lowest_team_a:
                lowest_team_a_bookermaker += ', ' + bookmaker['title']
            if team_b_implied_prob < lowest_team_b:
                lowest_team_b = team_b_implied_prob
                lowest_team_b_bookermaker = bookmaker['title']
            elif team_b_implied_prob == lowest_team_b:
                lowest_team_b_bookermaker += ', ' + bookmaker['title']

    if print_output:
        print('Best odds across all bookmakers:')
        print(lowest_team_a_bookermaker, ' - ', game['home_team'], ' - implied probability:', lowest_team_a)
        print(lowest_team_b_bookermaker, ' - ', game['away_team'], ' - implied probability:', lowest_team_b)
    
    return {
        'home_team': game['home_team'],
        'away_team': game['away_team'],
        'commence_time': game['commence_time'],
        'best_odds': {
            game['home_team']: {
                'implied_prob': lowest_team_a,
                'bookmaker': lowest_team_a_bookermaker
            },
            game['away_team']: {
                'implied_prob': lowest_team_b,
                'bookmaker': lowest_team_b_bookermaker
            }
        }
    }

# %%
valid_bookmakers = ['DraftKings', 'BetMGM', 'Caesars', 'FanDuel', 'ESPN BET']

for game in odds_response.json():
    processed_game = process_game(game, valid_bookmakers, print_output=False)
    sum = processed_game['best_odds'][processed_game['home_team']]['implied_prob'] + processed_game['best_odds'][processed_game['away_team']]['implied_prob']
    if sum < 2.015:
        print(processed_game['home_team'] + ' vs ' + processed_game['away_team'])
        print(processed_game['commence_time'])
        print('---')
        for team, odds in processed_game['best_odds'].items():
            print(odds['bookmaker'])
            print(team + ': ' + str(odds['implied_prob']))
        print(sum)
        print('######################################################################')
# Out:
# Buffalo Bills vs Miami Dolphins
# 2025-09-19T00:15:00Z
# ---
# DraftKings, FanDuel
# Buffalo Bills: 0.8928571428571428
# BetMGM
# Miami Dolphins: 0.14285714285714285
# 1.0357142857142856
# ######################################################################
# Carolina Panthers vs Atlanta Falcons
# 2025-09-21T17:00:00Z
# ---
# ESPN BET, BetMGM
# Carolina Panthers: 0.3333333333333333
# DraftKings
# Atlanta Falcons: 0.684931506849315
# 1.0182648401826484
# ######################################################################
# Minnesota Vikings vs Cincinnati Bengals
# 2025-09-21T17:00:00Z
# ---
# FanDuel
# Minnesota Vikings: 0.5952380952380952
# DraftKings
# Cincinnati Bengals: 0.42372881355932207
# 1.0189669087974174
# ######################################################################
# Cleveland Browns vs Green Bay Packers
# 2025-09-21T17:00:00Z
# ---
# DraftKings
# Cleveland Browns: 0.20833333333333334
# BetMGM
# Green Bay Packers: 0.8064516129032259
# 1.0147849462365592
# ######################################################################
# Jacksonville Jaguars vs Houston Texans
# 2025-09-21T17:00:00Z
# ---
# ESPN BET
# Jacksonville Jaguars: 0.5464480874316939
# FanDuel
# Houston Texans: 0.4854368932038835
# 1.0318849806355774
# ######################################################################
# Washington Commanders vs Las Vegas Raiders
# 2025-09-21T17:00:00Z
# ---
# DraftKings, ESPN BET
# Washington Commanders: 0.6369426751592356
# FanDuel
# Las Vegas Raiders: 0.390625
# 1.0275676751592355
# ######################################################################
# New England Patriots vs Pittsburgh Steelers
# 2025-09-21T17:00:00Z
# ---
# ESPN BET, FanDuel, BetMGM
# New England Patriots: 0.47619047619047616
# DraftKings
# Pittsburgh Steelers: 0.5555555555555556
# 1.0317460317460316
# ######################################################################
# Tampa Bay Buccaneers vs New York Jets
# 2025-09-21T17:00:00Z
# ---
# ESPN BET, BetMGM
# Tampa Bay Buccaneers: 0.7633587786259541
# DraftKings
# New York Jets: 0.2597402597402597
# 1.023099038366214
# ######################################################################
# Tennessee Titans vs Indianapolis Colts
# 2025-09-21T17:01:00Z
# ---
# FanDuel
# Tennessee Titans: 0.3676470588235294
# DraftKings
# Indianapolis Colts: 0.6622516556291391
# 1.0298987144526686
# ######################################################################
# Philadelphia Eagles vs Los Angeles Rams
# 2025-09-21T17:01:00Z
# ---
# DraftKings
# Philadelphia Eagles: 0.6493506493506493
# ESPN BET, FanDuel
# Los Angeles Rams: 0.3846153846153846
# 1.033966033966034
# ######################################################################
# Los Angeles Chargers vs Denver Broncos
# 2025-09-21T20:05:00Z
# ---
# ESPN BET
# Los Angeles Chargers: 0.5847953216374269
# FanDuel
# Denver Broncos: 0.4310344827586207
# 1.0158298043960476
# ######################################################################
# Seattle Seahawks vs New Orleans Saints
# 2025-09-21T20:05:00Z
# ---
# DraftKings, ESPN BET, FanDuel
# Seattle Seahawks: 0.7936507936507936
# FanDuel, BetMGM
# New Orleans Saints: 0.24390243902439027
# 1.037553232675184
# ######################################################################
# Chicago Bears vs Dallas Cowboys
# 2025-09-21T20:25:00Z
# ---
# ESPN BET, BetMGM
# Chicago Bears: 0.5128205128205129
# FanDuel
# Dallas Cowboys: 0.5181347150259068
# 1.0309552278464196
# ######################################################################
# San Francisco 49ers vs Arizona Cardinals
# 2025-09-21T20:26:00Z
# ---
# FanDuel
# San Francisco 49ers: 0.5952380952380952
# BetMGM
# Arizona Cardinals: 0.4166666666666667
# 1.0119047619047619
# ######################################################################
# New York Giants vs Kansas City Chiefs
# 2025-09-22T00:21:00Z
# ---
# DraftKings
# New York Giants: 0.2777777777777778
# FanDuel
# Kansas City Chiefs: 0.7299270072992701
# 1.0077047850770477
# ######################################################################
# Baltimore Ravens vs Detroit Lions
# 2025-09-23T00:15:00Z
# ---
# DraftKings
# Baltimore Ravens: 0.6944444444444444
# FanDuel
# Detroit Lions: 0.33557046979865773
# 1.030014914243102
# ######################################################################
# Arizona Cardinals vs Seattle Seahawks
# 2025-09-26T00:16:00Z
# ---
# DraftKings
# Arizona Cardinals: 0.5649717514124294
# FanDuel
# Seattle Seahawks: 0.4629629629629629
# 1.0279347143753923
# ######################################################################
# Pittsburgh Steelers vs Minnesota Vikings
# 2025-09-28T13:31:00Z
# ---
# DraftKings
# Pittsburgh Steelers: 0.5555555555555556
# FanDuel
# Minnesota Vikings: 0.4504504504504504
# 1.006006006006006
# ######################################################################
# Atlanta Falcons vs Washington Commanders
# 2025-09-28T17:01:00Z
# ---
# DraftKings
# Atlanta Falcons: 0.48780487804878053
# FanDuel
# Washington Commanders: 0.5405405405405405
# 1.028345418589321
# ######################################################################
# Buffalo Bills vs New Orleans Saints
# 2025-09-28T17:01:00Z
# ---
# DraftKings
# Buffalo Bills: 0.9009009009009008
# FanDuel
# New Orleans Saints: 0.11764705882352941
# 1.0185479597244302
# ######################################################################
# New England Patriots vs Carolina Panthers
# 2025-09-28T17:01:00Z
# ---
# FanDuel
# New England Patriots: 0.6993006993006994
# DraftKings
# Carolina Panthers: 0.3225806451612903
# 1.0218813444619896
# ######################################################################
# Detroit Lions vs Cleveland Browns
# 2025-09-28T17:01:00Z
# ---
# FanDuel
# Detroit Lions: 0.8333333333333334
# DraftKings
# Cleveland Browns: 0.2040816326530612
# 1.0374149659863945
# ######################################################################
# Houston Texans vs Tennessee Titans
# 2025-09-28T17:01:00Z
# ---
# DraftKings
# Houston Texans: 0.7575757575757576
# FanDuel
# Tennessee Titans: 0.2531645569620253
# 1.010740314537783
# ######################################################################
# New York Giants vs Los Angeles Chargers
# 2025-09-28T17:01:00Z
# ---
# FanDuel
# New York Giants: 0.31746031746031744
# DraftKings
# Los Angeles Chargers: 0.7042253521126761
# 1.0216856695729937
# ######################################################################
# Tampa Bay Buccaneers vs Philadelphia Eagles
# 2025-09-28T17:01:00Z
# ---
# FanDuel
# Tampa Bay Buccaneers: 0.4385964912280702
# DraftKings
# Philadelphia Eagles: 0.5952380952380952
# 1.0338345864661656
# ######################################################################
# Los Angeles Rams vs Indianapolis Colts
# 2025-09-28T20:06:00Z
# ---
# FanDuel
# Los Angeles Rams: 0.6896551724137931
# DraftKings
# Indianapolis Colts: 0.3278688524590164
# 1.0175240248728095
# ######################################################################
# San Francisco 49ers vs Jacksonville Jaguars
# 2025-09-28T20:06:00Z
# ---
# FanDuel
# San Francisco 49ers: 0.6134969325153374
# DraftKings
# Jacksonville Jaguars: 0.3787878787878788
# 0.9922848113032162
# ######################################################################
# Kansas City Chiefs vs Baltimore Ravens
# 2025-09-28T20:26:00Z
# ---
# FanDuel
# Kansas City Chiefs: 0.4587155963302752
# DraftKings
# Baltimore Ravens: 0.5747126436781609
# 1.033428240008436
# ######################################################################
# Las Vegas Raiders vs Chicago Bears
# 2025-09-28T20:26:00Z
# ---
# DraftKings
# Las Vegas Raiders: 0.5555555555555556
# FanDuel
# Chicago Bears: 0.4807692307692307
# 1.0363247863247862
# ######################################################################
# Dallas Cowboys vs Green Bay Packers
# 2025-09-29T00:21:00Z
# ---
# FanDuel
# Dallas Cowboys: 0.33557046979865773
# DraftKings
# Green Bay Packers: 0.684931506849315
# 1.0205019766479728
# ######################################################################
# Miami Dolphins vs New York Jets
# 2025-09-29T23:16:00Z
# ---
# DraftKings
# Miami Dolphins: 0.5747126436781609
# FanDuel
# New York Jets: 0.4504504504504504
# 1.0251630941286112
# ######################################################################
# Denver Broncos vs Cincinnati Bengals
# 2025-09-30T00:16:00Z
# ---
# FanDuel
# Denver Broncos: 0.7246376811594204
# DraftKings
# Cincinnati Bengals: 0.3076923076923077
# 1.032329988851728
# ######################################################################

# %%
# This is for individual bookmakers only

valid_bookmakers = ['BetMGM']

for game in odds_response.json():
    processed_game = process_game(game, valid_bookmakers, print_output=False)
    sum = processed_game['best_odds'][processed_game['home_team']]['implied_prob'] + processed_game['best_odds'][processed_game['away_team']]['implied_prob']
    best_odds = max(processed_game['best_odds'][processed_game['home_team']]['implied_prob'], processed_game['best_odds'][processed_game['away_team']]['implied_prob'])
    if sum < 2:
        # print(processed_game['home_team'] + ' vs ' + processed_game['away_team'])
        # print(processed_game['commence_time'])
        # print('---')
        for team, odds in processed_game['best_odds'].items():
            # print(odds['bookmaker'])
            print(team + ': ' + str(odds['implied_prob']))
        print(sum)
        print('######################################################################')
# Out:
# Houston Cougars: 0.3921568627450981
# Colorado Buffaloes: 0.6535947712418301
# 1.0457516339869282
# ######################################################################
# Arizona Wildcats: 0.5128205128205129
# Kansas State Wildcats: 0.53475935828877
# 1.0475798711092827
# ######################################################################
# UCLA Bruins: 0.17391304347826086
# New Mexico Lobos: 0.8695652173913044
# 1.0434782608695654
# ######################################################################
# Alabama Crimson Tide: 0.9523809523809523
# Wisconsin Badgers: 0.09523809523809523
# 1.0476190476190474
# ######################################################################
# Kent State Golden Flashes: 0.9615384615384615
# Buffalo Bulls: 0.08333333333333333
# 1.0448717948717947
# ######################################################################
# Michigan Wolverines: 0.058823529411764705
# Central Michigan Chippewas: 0.9803921568627451
# 1.0392156862745097
# ######################################################################
# Georgia Tech Yellow Jackets: 0.591715976331361
# Clemson Tigers: 0.45454545454545453
# 1.0462614308768154
# ######################################################################
# Troy Trojans: 0.6493506493506493
# Memphis Tigers: 0.4
# 1.0493506493506493
# ######################################################################
# Northwestern Wildcats: 0.047619047619047616
# Oregon Ducks: 0.9900990099009901
# 1.0377180575200378
# ######################################################################
# Temple Owls: 0.9615384615384615
# Oklahoma Sooners: 0.08695652173913043
# 1.0484949832775918
# ######################################################################
# Auburn Tigers: 0.9803921568627451
# South Alabama Jaguars: 0.06896551724137931
# 1.0493576741041244
# ######################################################################
# Missouri Tigers: 0.047619047619047616
# Louisiana Ragin Cajuns: 0.9900990099009901
# 1.0377180575200378
# ######################################################################
# Delaware Blue Hens: 0.2777777777777778
# UConn Huskies: 0.7633587786259541
# 1.0411365564037318
# ######################################################################
# Tennessee Volunteers: 0.6493506493506493
# Georgia Bulldogs: 0.4
# 1.0493506493506493
# ######################################################################
# Missouri State Bears: 0.05555555555555555
# SMU Mustangs: 0.9900990099009901
# 1.0456545654565457
# ######################################################################
# North Texas Mean Green: 0.6756756756756757
# Washington State Cougars: 0.37037037037037035
# 1.0460460460460461
# ######################################################################
# Texas Tech Red Raiders: 0.08333333333333333
# Oregon State Beavers: 0.9615384615384615
# 1.0448717948717947
# ######################################################################
# West Virginia Mountaineers: 0.7518796992481203
# Pittsburgh Panthers: 0.29411764705882354
# 1.0459973463069439
# ######################################################################
# Purdue Boilermakers: 0.1111111111111111
# USC Trojans: 0.9345794392523364
# 1.0456905503634475
# ######################################################################
# Arkansas State Red Wolves: 0.10256410256410256
# Iowa State Cyclones: 0.9433962264150942
# 1.0459603289791968
# ######################################################################
# Miami Hurricanes: 0.9009009009009008
# South Florida Bulls: 0.14285714285714285
# 1.0437580437580436
# ######################################################################
# Bowling Green Falcons: 0.37735849056603776
# Liberty Flames: 0.6666666666666666
# 1.0440251572327044
# ######################################################################
# Nevada Wolf Pack: 0.2631578947368421
# Middle Tennessee Blue Raiders: 0.7751937984496123
# 1.0383516931864545
# ######################################################################
# Florida International Panthers: 0.47619047619047616
# Florida Atlantic Owls: 0.5747126436781609
# 1.0509031198686372
# ######################################################################
# Southern Mississippi Golden Eagles: 0.6369426751592356
# Appalachian State Mountaineers: 0.4081632653061224
# 1.045105940465358
# ######################################################################
# Ole Miss Rebels: 0.3389830508474576
# Arkansas Razorbacks: 0.6993006993006994
# 1.038283750148157
# ######################################################################
# Georgia Southern Eagles: 0.6172839506172839
# Jacksonville State Gamecocks: 0.425531914893617
# 1.042815865510901
# ######################################################################
# Illinois Fighting Illini: 0.9900990099009901
# Western Michigan Broncos: 0.047619047619047616
# 1.0377180575200378
# ######################################################################
# Virginia Tech Hokies: 0.35714285714285715
# Old Dominion Monarchs: 0.6896551724137931
# 1.0467980295566504
# ######################################################################
# South Carolina Gamecocks: 0.6172839506172839
# Vanderbilt Commodores: 0.425531914893617
# 1.042815865510901
# ######################################################################
# Coastal Carolina Chanticleers: 0.2777777777777778
# East Carolina Pirates: 0.7633587786259541
# 1.0411365564037318
# ######################################################################
# Kentucky Wildcats: 0.07142857142857142
# Eastern Michigan Eagles: 0.970873786407767
# 1.0423023578363384
# ######################################################################
# LSU Tigers: 0.3076923076923077
# Florida Gators: 0.7407407407407407
# 1.0484330484330484
# ######################################################################
# Louisiana Tech Bulldogs: 0.7874015748031495
# New Mexico State Aggies: 0.2631578947368421
# 1.0505594695399916
# ######################################################################
# Notre Dame Fighting Irish: 0.6993006993006994
# Texas A&M Aggies: 0.3448275862068966
# 1.044128285507596
# ######################################################################
# Tulane Green Wave: 0.5
# Duke Blue Devils: 0.5464480874316939
# 1.046448087431694
# ######################################################################
# Tulsa Golden Hurricane: 0.8620689655172414
# Navy Midshipmen: 0.18181818181818182
# 1.0438871473354232
# ######################################################################
# Wyoming Cowboys: 0.970873786407767
# Utah Utes: 0.07142857142857142
# 1.0423023578363384
# ######################################################################
# UAB Blazers: 0.2222222222222222
# Akron Zips: 0.819672131147541
# 1.0418943533697633
# ######################################################################
# Utah State Aggies: 0.6666666666666666
# Air Force Falcons: 0.37735849056603776
# 1.0440251572327044
# ######################################################################
# Arizona State Sun Devils: 0.9009009009009008
# Texas State Bobcats: 0.14285714285714285
# 1.0437580437580436
# ######################################################################
# Stanford Cardinal: 0.8547008547008548
# Boston College Eagles: 0.19047619047619047
# 1.0451770451770452
# ######################################################################
# California Golden Bears: 0.45454545454545453
# Minnesota Golden Gophers: 0.591715976331361
# 1.0462614308768154
# ######################################################################
